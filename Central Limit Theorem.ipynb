# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
df = pd.read_csv(r'C:\Users\user\Downloads\adult.csv')

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
sns.distplot(df.age)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.shape
# Out:
# (48842, 15)

# %%
random.seed(0)
samples = random.sample(range(0,48842),50)
print(samples)
# Out:
# [25247, 27562, 2653, 16968, 33506, 31845, 26537, 19877, 31234, 23465, 38232, 14315, 33075, 9127, 18470, 9158, 6214, 40525, 16417, 34902, 46214, 39446, 9631, 20325, 6472, 47830, 4832, 44825, 21639, 30942, 36687, 6599, 23186, 28453, 20722, 40035, 41970, 13400, 36210, 31261, 29012, 34167, 17071, 4081, 35959, 920, 6112, 47166, 26137, 46547]

# %%
df.iloc[samples]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 25247   43           Private   99212     Assoc-voc               11
# 27562   18           Private  329054          11th                7
# 2653    62  Self-emp-not-inc  162245     Bachelors               13
# 16968   45         Local-gov   86644     Bachelors               13
# 33506   49           Private  239865          11th                7
# 31845   34           Private  200192  Some-college               10
# 26537   45           Private  253116          10th                6
# 19877   19           Private  182355  Some-college               10
# 31234   56           Private  121362     Bachelors               13
# 23465   42           Private  168103     Bachelors               13
# 38232   21  Self-emp-not-inc  103277          12th                8
# 14315   36                 ?  172775  Some-college               10
# 33075   18                 ?  256179  Some-college               10
# ...

# %%
df.iloc[samples].age.mean()
# Out:
# 39.78

# %%
sample_mean = {}
means = []
for i in range(100):
    samples = random.sample(range(0,48842),50)
    means.append(df.iloc[samples].age.mean())
sample_mean['100sam_with_50ele'] = means

# %%
np.mean(sample_mean['100sam_with_50ele'])
# Out:
# 38.71020000000001

# %%
sns.distplot(sample_mean['100sam_with_50ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(100):
    samples = random.sample(range(0,48842),100)
    means.append(df.iloc[samples].age.mean())
sample_mean['100sam_with_100ele'] = means

# %%
np.mean(sample_mean['100sam_with_100ele'])
# Out:
# 38.649300000000004

# %%
sns.distplot(sample_mean['100sam_with_100ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(1000):
    samples = random.sample(range(0,48842),100)
    means.append(df.iloc[samples].age.mean())
sample_mean['1000sam_with_100ele'] = means

# %%
sns.distplot(sample_mean['1000sam_with_100ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(1000):
    samples = random.sample(range(0,48842),50)
    means.append(df.iloc[samples].age.mean())
sample_mean['1000sam_with_50ele'] = means

# %%
sns.distplot(sample_mean['1000sam_with_50ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(1000):
    samples = random.sample(range(0,48842),10)
    means.append(df.iloc[samples].age.mean())
sample_mean['1000sam_with_10ele'] = means

# %%
sns.distplot(sample_mean['1000sam_with_10ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(1000):
    samples = random.sample(range(0,48842),4)
    means.append(df.iloc[samples].age.mean())
sample_mean['1000sam_with_4ele'] = means

# %%
sns.distplot(sample_mean['1000sam_with_4ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(1000):
    samples = random.sample(range(0,48842),400)
    means.append(df.iloc[samples].age.mean())
sample_mean['1000sam_with_400ele'] = means

# %%
sns.distplot(sample_mean['1000sam_with_400ele'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
np.array(sample_mean['1000sam_with_400ele']).std()
# Out:
# 0.6761606097620224

# %%
print(sample_mean.keys())
# Out:
# dict_keys(['100sam_with_50ele', '100sam_with_100ele', '1000sam_with_100ele', '1000sam_with_50ele', '1000sam_with_10ele', '1000sam_with_4ele', '1000sam_with_400ele'])

# %%
np.array(sample_mean['1000sam_with_100ele']).std()
# Out:
# 1.3485032419686651

# %%
df.age.std()
# Out:
# 13.71050993444322

# %%
13.7/20
# Out:
# 0.6849999999999999

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,3,2)
sns.distplot(sample_mean['100sam_with_50ele'])
plt.title("100 samples with 50 elements")

plt.subplot(2,3,4)
sns.distplot(sample_mean['100sam_with_100ele'])
plt.title("100 samples with 100 elements")

plt.subplot(2,3,3)
sns.distplot(sample_mean['1000sam_with_50ele'])
plt.title("1000 samples with 50 elements")

plt.subplot(2,3,5)
sns.distplot(sample_mean['1000sam_with_100ele'])
plt.title("1000 samples with 100 elements")

plt.subplot(2,3,1)
sns.distplot(sample_mean['1000sam_with_4ele'])
plt.title("1000 samples with 4 elements")

plt.subplot(2,3,6)
sns.distplot(sample_mean['1000sam_with_400ele'])
plt.title("1000 samples with 400 elements")

plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
